# %%
import pandas as pd
import numpy as np

# %%
oldbooks = pd.read_csv('titleISBNdateFiction.orig.csv', index_col = 'ISBN')
newbooks = pd.read_csv('titleISBNdateFiction.csv', index_col = 'ISBN')

# %%
oldbooks
# Out:
#                                           Title   FirstDate    LastDate
# ISBN
# 038553714X                        GRAY MOUNTAIN   11/9/2014   4/12/2015
# 031621096X                          HOPE TO DIE  12/14/2014    3/1/2015
# 141659485X                THE CHRISTMAS SWEATER  11/30/2008   1/10/2010
# 1455520616                               SEE ME   11/1/2015   3/13/2016
# 1455521205                           THE TARGET   5/11/2014   7/13/2014
# 045146317X                              CHANGES   4/25/2010   5/16/2010
# 141659518X                    AMERICAN ASSASSIN  10/31/2010    1/9/2011
# 147674906X       I&#39;VE GOT YOU UNDER MY SKIN   4/20/2014   5/25/2014
# 1401324436                           HEAT RISES   10/9/2011   12/4/2011
# 1455559822                           MEMORY MAN   5/10/2015   7/19/2015
# 1594633665                THE GIRL ON THE TRAIN    2/1/2015   4/10/2016
# 1451658907         THE WIND THROUGH THE KEYHOLE   5/13/2012    7/8/2012
# ...

# %%
newbooks
# Out:
#                                           Title   FirstDate    LastDate
# ISBN
# 0316037915                            TICK TOCK  2011-02-13  2011-04-03
# 0446572993                         THE INNOCENT  2012-05-06  2012-07-22
# 0385341679                          SHADOWFEVER  2011-02-06  2011-03-06
# 0061374229          THE STORY OF EDGAR SAWTELLE  2008-06-29  2009-04-05
# 038553714X                        GRAY MOUNTAIN  2014-11-09  2015-04-12
# 031621096X                          HOPE TO DIE  2014-12-14  2015-03-01
# 0345527771                      WICKED BUSINESS  2012-07-08  2012-08-19
# 0316018767                   THE 8TH CONFESSION  2009-05-17  2009-07-12
# 0062255657     THE OCEAN AT THE END OF THE LANE  2013-07-07  2013-09-29
# 0399164456                        THE COLLECTOR  2014-05-04  2014-06-08
# 0385539436                         ROGUE LAWYER  2015-11-08  2016-03-20
# 141659485X                THE CHRISTMAS SWEATER  2008-11-30  2010-01-10
# ...

# %%
oldlist = oldbooks.index.tolist()
newlist = newbooks.index.tolist()

# %%
oldlist
# Out:
# ['038553714X',
#  '031621096X',
#  '141659485X',
#  '1455520616',
#  '1455521205',
#  '045146317X',
#  '141659518X',
#  '147674906X',
#  '1401324436',
#  '1455559822',
#  '1594633665',
#  '1451658907',
#  '030758836X',
#  '031621129X',
#  '1451668945',
#  '141654383X',
#  '140006712X',
#  '1416570861',
#  '044654759X',
#  '1451668864',
#  '031621082X',
#  '044101819X',
#  '031603617X',
#  '1476727651',
#  '045146379X',
#  '1416595201',
#  '1476754454',
#  '006232005X',
#  '1439172269',
#  '1455521213',
#  '031640702X',
#  '1101965495',
#  '1250022061',
#  '1451627289',
#  '030726999X',
#  '1476770387',
#  '044654695X',
#  '1455520659',
#  '1501100076',
#  '1250061628',
#  '039915597X',
#  '052595158X',
#  '038541305X',
#  '1439102767',
#  '1416563067',
#  '1476783454',
#  '141659521X',
#  '1439184305',
#  '1439148503',
#  '1501111671',
#  '1455521191',
#  '1401322786',
#  '039916443X',
#  '193700788X',
#  '1439102740',
#  '1476717125',
#  '1400067693',
#  '1439102414',
# ...

# %%
dupl = 0
for x in oldlist:
    if x in newlist:
        dupl += 1

# %%
dupl
# Out:
# 1042

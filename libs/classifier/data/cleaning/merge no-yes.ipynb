# %%
import pandas as pd
import numpy as np

# %%
no = pd.read_csv('no.csv')
yes = pd.read_csv('yes.csv')

# %%
no['on_NYT'] = np.zeros(no.shape[0])
yes['on_NYT'] = np.ones(yes.shape[0])

# %%
no
# Out:
#             ISBN                                          Publisher  \
# 0     1400052920                                      Harmony Books
# 1     076790818X                                     Broadway Books
# 2     076790382X                                           Broadway
# 3     193337201X                                    Europa Editions
# 4     097669400X                                Pragmatic Bookshelf
# 5     1557344493                          Teacher Created Resources
# 6     1575606240                                  Cherry Lane Music
# 7     1595580271                                          New Press
# 8     1595962808                               Changeling Press LLC
# 9     1590301943                                          Shambhala
# 10    006076273X                                        HarperAudio
# 11    1932386106                               Archaia Studio Press
# 12    1596670231                                  Eye on Education,
# ...

# %%
yes
# Out:
#             ISBN                      Publisher     Dewey  \
# 0     0553807056                   Bantam Books   813'.54
# 1     0316068047       Little Brown and Company       NaN
# 2     0312348673             St. Martin's Press       NaN
# 3     0399154183             G.P. Putnam's Sons       NaN
# 4     0385517882                      Doubleday       NaN
# 5     0399155007                   Putnam Adult       NaN
# 6     0446195979       Grand Central Publishing       NaN
# 7     0441015891                  Ace Hardcover       NaN
# 8     1416566384               Simon & Schuster       NaN
# 9     0778325504                           Mira       NaN
# 10    0061160873        HarperCollinsPublishers       NaN
# 11    0307265730                          Knopf   813/.54
# 12    0061537934                  HarperCollins   813/.54
# 13    0525950605                   Dutton Adult       NaN
# 14    0061236217                         Harper   813/.54
# ...

# %%
combined_noyes = [no, yes]
df_combined = pd.concat(combined_noyes)

# %%
df_combined
# Out:
#             ISBN                      Publisher      Dewey  \
# 0     1400052920                  Harmony Books   823/.914
# 1     076790818X                 Broadway Books        500
# 2     076790382X                       Broadway        NaN
# 3     193337201X                Europa Editions        NaN
# 4     097669400X            Pragmatic Bookshelf        NaN
# 5     1557344493      Teacher Created Resources        NaN
# 6     1575606240              Cherry Lane Music        NaN
# 7     1595580271                      New Press        NaN
# 8     1595962808           Changeling Press LLC        NaN
# 9     1590301943                      Shambhala        NaN
# 10    006076273X                    HarperAudio        NaN
# 11    1932386106           Archaia Studio Press        NaN
# 12    1596670231              Eye on Education,        NaN
# 13    1581807740              North Light Books  745.594/2
# 14    1852402873           Sovereign Publishing        NaN
# ...

# %%
df_combined.to_csv('books_dataset_v1.csv')

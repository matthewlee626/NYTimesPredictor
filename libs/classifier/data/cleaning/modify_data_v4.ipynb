# %%
import pandas as pd
import numpy as np

# %%
books_ds = pd.read_csv('books_dataset_v4.csv', index_col='ISBN')

# %%
books_ds
# Out:
#                                 Publisher      Dewey                       LC  \
# ISBN
# 1400052920                  Harmony Books   823/.914     PR6051.D3352 H5 1979
# 076790818X                 Broadway Books        500           Q162 .B88 2004
# 076790382X                       Broadway        NaN                      NaN
# 193337201X                Europa Editions        NaN                      NaN
# 097669400X            Pragmatic Bookshelf        NaN                      NaN
# 1557344493      Teacher Created Resources        NaN                      NaN
# 1575606240              Cherry Lane Music        NaN                      NaN
# 1595580271                      New Press        NaN                      NaN
# 1595962808           Changeling Press LLC        NaN                      NaN
# 1590301943                      Shambhala        NaN                      NaN
# 006076273X                    HarperAudio        NaN                      NaN
# ...

# %%
# Out:
# Publisher              Sovereign Publishing
# Dewey                                   NaN
# LC                                      NaN
# Title                 There's Always Enough
# Number of Pages                         192
# Publish Place                           NaN
# Subject Place                             0
# Subject                                   0
# Publish Date                           2003
# on_NYT                                    0
# publisher_id                            735
# publishplace_id                           0
# dewey_id                                  0
# publisher_freq                            0
# publish_place_freq                        0
# dewey_freq                                0
# Author                                  NaN
# author_id                                 0
# author_frequency                          0
# Name: 1852402873, dtype: object

# %%
formatted_title_word_counts = []
for x in books_ds['Title']:
    strlen = len(x.strip().split(' '))
    formatted_title_word_counts.append(strlen)
    if strlen>10:
        print(x, strlen)
formatted_title_word_counts
# Out:
# A guide for using A wrinkle in time in the classroom 11
# The Portrait of a Lady (Barnes & Noble Classics Series) (Barnes & Noble Classics) 14
# Cien Años de Soledad/ 100 Years of Solitude (Nueva Austral Series, Vol. 100) 13
# Love As A Foreign Language #5 (Love as a Foreign Language) 11
# Richest Man in Babylon - The Success Secrets of the Ancients 11
# Men are From Mars, Women are From Venus Low Price CD 11
# The Confessions: Saint Augustine (Works of Saint Augustine, a Translation for the 21st Century: Part 1- Books) 17
# Huck Finn; Pudd'nhead Wilson; No. 44, the mysterious stranger; and other writings 12
# Heart of darkness ; with, The Congo diary ; and, Up-river book 12
# La Verdad Acerca De Las Industrias Farmaceuticas/ the Truth About the Drug Companies 13
# Pirates of the Caribbean: Jack Sparrow #3: The Pirate Chase (Pirates of the Caribbean: Jack Sparrow) 16
# Pirates of the Caribbean: Jack Sparrow #2: The Siren Song (Pirates of the Caribbean: Jack Sparrow) 16
# ...

# %%
for i in range(books_ds.shape[0]):
    title = books_ds['Title'][i]
    if title.find('(') > -1 or len(title.strip().split(' ')) >= 9:
        print(i+2)
print(books_ds['Title'][11])
# Out:
# 21
# 23
# 30
# 37
# 38
# 39
# 42
# 67
# 69
# 71
# 72
# 86
# 90
# 102
# 115
# 123
# 129
# 137
# 138
# 145
# 151
# 161
# 168
# 172
# 197
# 199
# 206
# 219
# 241
# 242
# 243
# 245
# 246
# 249
# 268
# 280
# 296
# 298
# 309
# 315
# 316
# 327
# 342
# 360
# 368
# 376
# 383
# 389
# 406
# 407
# 418
# 426
# 440
# 478
# 487
# 489
# 490
# 492
# 493
# 495
# 496
# 504
# 506
# 513
# 517
# 521
# 533
# 547
# 552
# 559
# 561
# 565
# 573
# 574
# 576
# 577
# 601
# 610
# 612
# 613
# 614
# 621
# 622
# 625
# 626
# 645
# 646
# 649
# 651
# 653
# 655
# 657
# 663
# 664
# 665
# 667
# 701
# 708
# 711
# 714
# 733
# 737
# 746
# 747
# 750
# 777
# 788
# 807
# 815
# 817
# 822
# 839
# 841
# 852
# 854
# 856
# 865
# 875
# 881
# 884
# 898
# 901
# 902
# 914
# 915
# 927
# 937
# 938
# 945
# 953
# 954
# 963
# 975
# 981
# 988
# 991
# 1002
# 1003
# 1006
# 1007
# 1035
# 1039
# 1043
# 1055
# 1056
# 1057
# 1060
# 1067
# 1070
# 1074
# 1075
# 1082
# 1085
# 1086
# 1094
# 1104
# 1110
# 1111
# 1112
# 1113
# 1114
# 1116
# 1122
# 1139
# ...

# %%
import pandas as pd
import numpy as np

# %%
no_nyt = pd.read_csv('no.csv', index_col='LC')
yes_nyt = pd.read_csv('yes.csv', index_col='LC')

# %%
no_nyt
# Out:
#                                ISBN  \
# LC
# PR6051.D3352 H5 1979     1400052920
# Q162 .B88 2004           076790818X
# NaN                      076790382X
# NaN                      193337201X
# NaN                      097669400X
# NaN                      1557344493
# NaN                      1575606240
# NaN                      1595580271
# NaN                      1595962808
# NaN                      1590301943
# NaN                      006076273X
# NaN                      1932386106
# NaN                      1596670231
# TT860 .B688 2006         1581807740
# NaN                      1852402873
# NaN                      1581805632
# PR9619.3.C5964 P69 1996  034541005X
# HF5478 .G56 2005         006076287X
# PG3366 .A6 2003          1593080271
# NaN                      1593081774
# NaN                      1568491980
# NaN                      1557344035
# NaN                      043927169X
# PS3570.O37 L66 2006      006078671X
# PS3545.I464 N4 2004      1400032490
# ...

# %%
count = 0
for x in no_nyt.index:
    if str(x) in yes_nyt.index:
        count += 1

# %%
count
# Out:
# 0

# %%
uniquePub_no = {'0'}
for x in no_nyt.index:
    #if np.isnan(x)==False:
        uniquePub_no.add(x)

# %%
len(uniquePub_no)
# Out:
# 1575

# %%
uniquePub_no
# Out:
# {nan,
#  'Chetana Private Ltd',
#  'Fantasy Flight Games',
#  'Roseberg Pub',
#  'IBooks, Inc.',
#  'Editorial Diana',
#  'Charlesbridge Publishing',
#  'Basic Books Inc.,U.S.',
#  'Courage Books',
#  'GB Science Publishers SA',
#  'Ullstein Buchverlage GmbH & Co. KG / Ullstein Tas',
#  'Editorial Sudamericana / Mondadori',
#  'De Bezige Bij',
#  'Discovery House',
#  'Warner Adult',
#  'FASA Corporation',
#  'Riverhead Trade',
#  'Luna',
#  'Feral House',
#  'New Press',
#  'Nijgh & Van Ditmar',
#  'Bert Baker',
#  'Editorial Presenca',
#  'Aladdin Paperbacks',
#  'Prima Games',
#  'Roca Editorial',
#  "Teacher's Pet Publications, Inc.",
#  'Bruno Gmunder Verlag Gmbh',
#  'Kuperard',
#  'Loewe Vlg., Bindlach',
#  'CMX',
#  'VeloPress',
#  'Insel Verlag',
#  'Perennial',
#  'Workman Pub.',
#  'Anchor Books, Doubleday',
#  'Samuel French',
#  'WATKINS PUBLISHING LTD',
#  'New English Library Ltd',
#  'Nicholas Brealey Publishing',
#  'Quarry Press',
#  'Avalon Travel Publishing',
# ...

# %%
uniquePub_yes = {'0'}
for x in yes_nyt.index:
    #if np.isnan(x)==False:
        uniquePub_yes.add(x)

# %%
len(uniquePub_yes)
# Out:
# 221

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-ada16b30100f> in <module>
#       1 nancount_pd = 0
#       2 for x in no_nyt.index:
# ----> 3     if np.isnan(str(x)):
#       4         nancount_pd += 1
#       5 nancount_pd
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
